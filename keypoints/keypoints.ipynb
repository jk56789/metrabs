# %%
#여기 코드가 가장 중요하다. 위의 코드를 사용하면 matplot창을 띄워주고
# 아래의 코드를 사용하면 파이썬에서 첫번째 이미지만 보여준다.


#%matplotlib qt

# %matplotlib inline

# %% [markdown]
# ## 모델

# %%
import tensorflow as tf
import os

def download_model(model_type):
    server_prefix = 'https://omnomnom.vision.rwth-aachen.de/data/metrabs'
    model_zippath = tf.keras.utils.get_file(
        origin=f'{server_prefix}/{model_type}_20211019.zip',
        extract=True, cache_subdir='models')
    model_path = os.path.join(os.path.dirname(model_zippath), model_type)
    return model_path

model = tf.saved_model.load(download_model('metrabs_mob3l_y4t')) # or metrabs_eff2l_y4 for the big model
! wget -q https://raw.githubusercontent.com/isarandi/metrabs/master/img/test_image_3dpw.jpg
# Out:
# 'wget'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %% [markdown]
# ## 분석

# %%
import cv2
image = cv2.imread('C:/Users/Leeyourack/jookyoung/image/1.test_image/son1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
pred = model.detect_poses(image, skeleton='smpl_24')

# %% [markdown]
# 모델이 예측은 해주었지만 keypoints가 어디의 점들인지를 모른다. 구글링 실패. 함수 만들어서 확인해보자

# %% [markdown]
# ## 이미지 보여주는 함수

# %%
import matplotlib.pyplot as plt
def imshow(title = "image", image=None, size = 10):
    w,h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize = (size *aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_RGB2BGR))
    plt.title(title)
    plt.show()

# %%
image = cv2.imread('C:/Users/Leeyourack/jookyoung/image/1.test_image/son1.jpg')
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


p0 = pred['poses2d'].numpy()[:,0]
p1 = pred['poses2d'].numpy()[:,1]
p2 = pred['poses2d'].numpy()[:,2]
p3 = pred['poses2d'].numpy()[:,3]
p4 = pred['poses2d'].numpy()[:,4]
p5= pred['poses2d'].numpy()[:,5]
p6 = pred['poses2d'].numpy()[:,6]
p7 = pred['poses2d'].numpy()[:,7]
p8 = pred['poses2d'].numpy()[:,8]
p9 = pred['poses2d'].numpy()[:,9]
p10 = pred['poses2d'].numpy()[:,10]
p11 = pred['poses2d'].numpy()[:,11]
p12 = pred['poses2d'].numpy()[:,12]
p13= pred['poses2d'].numpy()[:,13]
p14 = pred['poses2d'].numpy()[:,14]
p15 = pred['poses2d'].numpy()[:,15]
p16 = pred['poses2d'].numpy()[:,16]
p17 = pred['poses2d'].numpy()[:,17]
p18 = pred['poses2d'].numpy()[:,18]
p19 = pred['poses2d'].numpy()[:,19]
p20 = pred['poses2d'].numpy()[:,20]
p21= pred['poses2d'].numpy()[:,21]
p22 = pred['poses2d'].numpy()[:,22]
p23 = pred['poses2d'].numpy()[:,23]


cv2.circle(image,(int(p0[0][0]),int(p0[0][1])), 5,(0,255,0),-1)
cv2.putText(image,'p0: 0spine',(int(p0[0][0]+10),int(p0[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p1[0][0]),int(p1[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p1: left hip',(int(p1[0][0]+10),int(p1[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p2[0][0]),int(p2[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p2: right hip',(int(p2[0][0]-220),int(p2[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p3[0][0]),int(p3[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p3: 3spine',(int(p3[0][0]+10),int(p3[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p4[0][0]),int(p4[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p4: left knee',(int(p4[0][0]+10),int(p4[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p5[0][0]),int(p5[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p5: right knee',(int(p5[0][0]-270),int(p5[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p6[0][0]),int(p6[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p6: 6spine',(int(p6[0][0]+10),int(p6[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p7[0][0]),int(p7[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p7: left anckle',(int(p7[0][0]+10),int(p7[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p8[0][0]),int(p8[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p8: right anckle',(int(p8[0][0]-270),int(p8[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p9[0][0]),int(p9[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p9: 9spine',(int(p9[0][0]+10),int(p9[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p10[0][0]),int(p10[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p10: left foot',(int(p10[0][0]+10),int(p10[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p11[0][0]),int(p11[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p11: right foot',(int(p11[0][0]-270),int(p11[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p12[0][0]),int(p12[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p12: neck ',(int(p12[0][0]+10),int(p12[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p13[0][0]),int(p13[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p13: ',(int(p13[0][0]+10),int(p13[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p14[0][0]),int(p14[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p14: ',(int(p14[0][0]+10),int(p14[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p15[0][0]),int(p15[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p15: head ',(int(p15[0][0]+10),int(p15[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p16[0][0]),int(p16[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p16: left shoulder',(int(p16[0][0]+10),int(p16[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p17[0][0]),int(p17[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p17: right shoulder ',(int(p17[0][0]-270),int(p17[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p18[0][0]),int(p18[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p18: left elbow',(int(p18[0][0]+10),int(p18[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p19[0][0]),int(p19[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p19: right elbow',(int(p19[0][0]-270),int(p19[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p20[0][0]),int(p20[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p20: left wrist ',(int(p20[0][0]+10),int(p20[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p21[0][0]),int(p21[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p21:right wrist',(int(p21[0][0]-270),int(p21[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p22[0][0]),int(p22[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p22: left hand',(int(p22[0][0]+10),int(p22[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)
cv2.circle(image,(int(p23[0][0]),int(p23[0][1])), 5, (0,255,0),-1)
cv2.putText(image,'p23: right hand ',(int(p23[0][0]-270),int(p23[0][1])),1,2,(255,255,255),2,cv2.LINE_AA)

imshow('keypoints',image)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from mpl_toolkits.mplot3d import Axes3D

def visualize(im, detections, poses3d, poses2d, edges):
    fig = plt.figure(figsize=(20, 10.4))
    image_ax = fig.add_subplot(1, 2, 1)
    image = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    image_ax.imshow(image)
    for x, y, w, h in detections[:, :4]:
        image_ax.add_patch(Rectangle((x, y), w, h, fill=False))
    

    '''#1
    pose_ax = fig.add_subplot(1, 2, 2, projection='3d')
    pose_ax.view_init(5, -85)
    pose_ax.set_xlim3d(-1500, 10000)
    pose_ax.set_zlim3d(-500, 6000)
    pose_ax.set_ylim3d(0, 20000)'''

  #2
    pose_ax = fig.add_subplot(1, 2, 2, projection='3d')
    pose_ax.view_init(21, -77)
    pose_ax.set_xlim3d(-1500, 1500)
    pose_ax.set_zlim3d(-500, 1500)
    pose_ax.set_ylim3d(0, 3000)



    # Matplotlib plots the Z axis as vertical, but our poses have Y as the vertical axis.
    # Therefore, we do a 90° rotation around the X axis:
    poses3d[..., 1], poses3d[..., 2] = poses3d[..., 2], -poses3d[..., 1]
    for pose3d, pose2d in zip(poses3d, poses2d):
        for i_start, i_end in edges:
            image_ax.plot(*zip(pose2d[i_start], pose2d[i_end]), marker='o', markersize=2)
            pose_ax.plot(*zip(pose3d[i_start], pose3d[i_end]), marker='o', markersize=2)
        image_ax.scatter(*pose2d.T, s=2)
        pose_ax.scatter(*pose3d.T, s=2)
        
        pose_ax.text(pose3d[0][0],pose3d[0][1],pose3d[0][2],'p0',color='red')
        pose_ax.text(pose3d[1][0],pose3d[1][1],pose3d[1][2],'p1',color='red')
        pose_ax.text(pose3d[2][0],pose3d[2][1],pose3d[2][2],'p2',color='red')
        pose_ax.text(pose3d[3][0],pose3d[3][1],pose3d[3][2],'p3',color='red')
        pose_ax.text(pose3d[4][0],pose3d[4][1],pose3d[4][2],'p4',color='red')
        pose_ax.text(pose3d[5][0],pose3d[5][1],pose3d[5][2],'p5',color='red')
        pose_ax.text(pose3d[6][0],pose3d[6][1],pose3d[6][2],'p6',color='red')
        pose_ax.text(pose3d[7][0],pose3d[7][1],pose3d[7][2],'p7',color='red')
        pose_ax.text(pose3d[8][0],pose3d[8][1],pose3d[8][2],'p8',color='red')
        pose_ax.text(pose3d[9][0],pose3d[9][1],pose3d[9][2],'p9',color='red')
        pose_ax.text(pose3d[10][0],pose3d[10][1],pose3d[10][2],'p10',color='red')
        pose_ax.text(pose3d[11][0],pose3d[11][1],pose3d[11][2],'p11',color='red')
        pose_ax.text(pose3d[12][0],pose3d[12][1],pose3d[12][2],'p12',color='red')
        pose_ax.text(pose3d[13][0],pose3d[13][1],pose3d[13][2],'p13',color='red')
        pose_ax.text(pose3d[14][0],pose3d[14][1],pose3d[14][2],'p14',color='red')
        pose_ax.text(pose3d[15][0],pose3d[15][1],pose3d[15][2],'p15',color='red')
        pose_ax.text(pose3d[16][0],pose3d[16][1],pose3d[16][2],'p16',color='red')
        pose_ax.text(pose3d[17][0],pose3d[17][1],pose3d[17][2],'p17',color='red')
        pose_ax.text(pose3d[18][0],pose3d[18][1],pose3d[18][2],'p18',color='red')
        pose_ax.text(pose3d[19][0],pose3d[19][1],pose3d[19][2],'p19',color='red')
        pose_ax.text(pose3d[20][0],pose3d[20][1],pose3d[20][2],'p20',color='red')
        pose_ax.text(pose3d[21][0],pose3d[21][1],pose3d[21][2],'p21',color='red')
        pose_ax.text(pose3d[22][0],pose3d[22][1],pose3d[22][2],'p22',color='red')
        pose_ax.text(pose3d[23][0],pose3d[23][1],pose3d[23][2],'p23',color='red')



        #pose_ax.text(*pose3d.T, s=2)

    fig.tight_layout()
    plt.show()

visualize(
    image, 
    pred['boxes'].numpy(),
    pred['poses3d'].numpy(),
    pred['poses2d'].numpy(),
    model.per_skeleton_joint_edges['smpl_24'].numpy())
