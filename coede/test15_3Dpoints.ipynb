# %%
#행렬2
import numpy as np
import cv2


before1 = np.float32([[346, 621],[844,431],[643, 147],[167,91]])
after1 = np.float32([[145,436],[335,436],[335,277],[145,277]])
M1 = cv2.getPerspectiveTransform(before1,after1)

before2 = np.float32([[195,303],[100,500],[943,713],[981,175]])
after2 = np.float32([[283,275],[391,275],[391,41],[283,41]])
M2 = cv2.getPerspectiveTransform(before2,after2)

before3 = np.float32([[304,577],[730,719],[933,130],[530,200]])
after3 = np.float32([[336,436],[474,436],[474,275],[336,275]]) 
M3 = cv2.getPerspectiveTransform(before3,after3)

# %%
#모델 yolo4
import tensorflow as tf
import os

def download_model(model_type):
    server_prefix = 'https://omnomnom.vision.rwth-aachen.de/data/metrabs'
    model_zippath = tf.keras.utils.get_file(
        origin=f'{server_prefix}/{model_type}.zip',
        extract=True, cache_subdir='models')
    model_path = os.path.join(os.path.dirname(model_zippath), model_type)
    return model_path

model = tf.saved_model.load(download_model('metrabs_rn18_y4'))

# %%
def draw_keypoints(frame,keypoints,percent):
    shaped = np.squeeze(keypoints)
    percent = np.squeeze(percent)
    for point in shaped:
        for per in percent:
            x,y = point
            a,b,c,d,per = percent
            if per > 0.9:
                cv2.circle(frame,(int(x),int(y)), 4, (0,255,0), -1)


def loop_through_people(frame ,keypoints_with,boxes_with):
    for idx, person in enumerate(keypoints_with):
        for i , box in enumerate(boxes_with):  
            if idx == i:
                draw_keypoints(frame,person,box)

# %%
#카메라 3대  원하는 영역에서 검출된 발만 mapping
#방향
##############################

import cv2
import datetime
import os

from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

# animation 만들기
from matplotlib import pyplot as plt
from celluloid import Camera
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

#여기 코드가 가장 중요하다. 위의 코드를 사용하면 matplot창을 띄워주고
# 아래의 코드를 사용하면 파이썬에서 첫번째 이미지만 보여준다.







ROI_image = cv2.imread('C:/Users/Leeyourack/jookyoung/image/0.ROI_image/preimage.png')
ROI_image = cv2.rectangle(ROI_image,[145,277],[335,436],(0,0,255),2)
ROI_image = cv2.rectangle(ROI_image,[283,41],[391,275],(0,255,0),2)
ROI_image = cv2.rectangle(ROI_image,[336,275],[474,436],(255,0,0),2)



def writeVideo():
    global ROI_image
    global ROI_image2
    
    #현재시간 가져오기
    currentTime = datetime.datetime.now()
    
    #RTSP를 불러오는 곳
    video_capture1 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test1.avi")
    video_capture2 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test2.avi")
    video_capture3 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test3.avi")
    

    # 웹캠 설정
    video_capture1.set(3, 800)  # 영상 가로길이 설정
    video_capture1.set(4, 600)  # 영상 세로길이 설정
    # 웹캠 설정
    video_capture2.set(3, 800)  # 영상 가로길이 설정
    video_capture2.set(4, 600)  # 영상 세로길이 설정
    # 웹캠 설정
    video_capture3.set(3, 800)  # 영상 가로길이 설정
    video_capture3.set(4, 600)  # 영상 세로길이 설정
    
    # 가로 길이 가져오기
    streaming_window_width = int(video_capture1.get(3))
    # 세로 길이 가져오기
    streaming_window_height = int(video_capture1.get(4))  

    # 가로 길이 가져오기
    streaming_window_width2 = int(video_capture2.get(3))
    # 세로 길이 가져오기
    streaming_window_height2 = int(video_capture2.get(4))  

   
    
    
    #현재 시간을 '년도 달 일 시간 분 초'로 가져와서 문자열로 생성
    fileName = str(currentTime.strftime('%Y %m %d %H %M %S'))

    #파일 저장하기 위한 변수 선언
    path1 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/0.5_test1.avi'
    #파일 저장하기 위한 변수 선언
    path2 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/0.5_test2.avi'
    #파일 저장하기 위한 변수 선언
    path3 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/0.5_test3.avi'
    #파일 저장하기 위한 변수 선언
    path4 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/0.5_test4-2.avi'
    #파일 저장하기 위한 변수 선언
    path5 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/0.5_test5.avi'
    
    # DIVX 코덱 적용 # 코덱 종류 # DIVX, XVID, MJPG, X264, WMV1, WMV2
    # 무료 라이선스의 이점이 있는 XVID를 사용
    fourcc = cv2.VideoWriter_fourcc('X', 'V', 'I', 'D')
    fps = 20
    # 비디오 저장
    # cv2.VideoWriter(저장 위치, 코덱, 프레임, (가로, 세로))
    out1 = cv2.VideoWriter(path1, fourcc, fps, (streaming_window_width, streaming_window_height))
    out2 = cv2.VideoWriter(path2, fourcc, fps, (streaming_window_width2, streaming_window_height2))
    out3 = cv2.VideoWriter(path3, fourcc, fps, (streaming_window_width, streaming_window_height))
    out4 = cv2.VideoWriter(path4, fourcc, fps, (1280, 540))
    out5 = cv2.VideoWriter(path5, fourcc, fps, (640, 480))
    box=[]


    # %matplotlib qt
    #%matplotlib inline
    # create figure object
    fig = plt.figure(figsize=(10, 5.2))
    # load axis box
    pose_ax = fig.add_subplot(1, 1, 1, projection='3d')
    # set axis limit
    pose_ax.view_init(40,-30 )
    pose_ax.set_xlim3d(-2000, 1500)
    pose_ax.set_zlim3d(-1500, 1500)
    pose_ax.set_ylim3d(10000, 0)
    # zip 함수를 사용해 병렬처리가
    #[ 316.1       -186.625     5880.8      ]
    camera = Camera(fig)


    
    
    while True:
        ROI_image = cv2.imread('C:/Users/Leeyourack/jookyoung/image/0.ROI_image/preimage.png')
        ROI_image = cv2.rectangle(ROI_image,[145,277],[335,436],(0,0,255),2)
        ROI_image = cv2.rectangle(ROI_image,[283,41],[391,275],(0,255,0),2)
        ROI_image = cv2.rectangle(ROI_image,[336,275],[474,436],(255,0,0),2)
        ROI_image2 = cv2.imread('C:/Users/Leeyourack/jookyoung/image/0.ROI_image/preimage.png')
        
        ret1, frame1 = video_capture1.read()
        ret2, frame2 = video_capture2.read()
        ret3, frame3 = video_capture3.read()
        
        img1 = frame1.copy()
        img2 = frame2.copy()
        img3 = frame3.copy()

        results1 = model.detect_poses(img1, skeleton='smpl_24')
        keypoints_with1 = results1['poses2d'].numpy()
        key3d1 = results1['poses3d'].numpy()
        boxes_1 = results1['boxes'].numpy()
        
        results2 = model.detect_poses(img2, skeleton='smpl_24')
        keypoints_with2 = results2['poses2d'].numpy()
        key3d2 = results2['poses3d'].numpy()
        boxes_2 = results2['boxes'].numpy()

        results3 = model.detect_poses(img3, skeleton='smpl_24')
        keypoints_with3 = results3['poses2d'].numpy()
        key3d2 = results3['poses3d'].numpy()
        boxes_3 = results3['boxes'].numpy()

        
        '''print('뒷 왼쪽발',pred['poses2d'].numpy()[:,7]) #뒷 왼쪽발
        print('뒷 오른쪽발',pred['poses2d'].numpy()[:,8]) #뒷 오른쪽발
        print('앞 왼쪽발',pred['poses2d'].numpy()[:,10]) # 앞 왼쪽발
        print('앞 오른쪽발',pred['poses2d'].numpy()[:,11]) # 앞 오른쪽발
        print('꼭지',pred['poses2d'].numpy()[:,10]/2+pred['poses2d'].numpy()[:,11]/2) # 꼭지'''
        
        
        
        loop_through_people(frame1, keypoints_with1, boxes_1) 
        loop_through_people(frame2, keypoints_with2, boxes_2)
        loop_through_people(frame3, keypoints_with3, boxes_3)

        camera_1 = results1['poses2d'].numpy()
        camera_2 = results2['poses2d'].numpy()
        camera_3 = results3['poses2d'].numpy()

        
        
        #########3d###########




        print(key3d1)
        edges = model.per_skeleton_joint_edges['smpl_24'].numpy()
        key3d1[..., 1], key3d1[..., 2] = key3d1[..., 2], -key3d1[..., 1]
        for pose3d in key3d1  :
            for i_start, i_end in edges:
                
                pose_ax.plot(*zip(pose3d[i_start], pose3d[i_end]), marker='o', markersize=2)
            print(key3d1)
            #image_ax.scatter(*pose2d.T, s=2)
            pose_ax.scatter(*pose3d.T, s=2)
            plt.pause(0.1)
           
            
            camera.snap()



        

    

        
        poly_list_1 = [(346, 621),(844,431),(643, 147),(167,91)] #[346, 621],[844,431],[643, 147],[167,91]
        poly_1 = Polygon(poly_list_1)
        for a,person1  in enumerate(camera_1):
            for q,box1 in enumerate(boxes_1):
                if box1[4] > 0.9 and a == q:
                    box.append(box1[4])
                    
                    
                    left_x_1 = person1[7][0]
                    left_y_1 = person1[7][1]
                    right_x_1 = person1[8][0]
                    right_y_1 = person1[8][1]
                    front_x_1 = person1[10][0]/2 + person1[11][0]/2
                    front_y_1 = person1[10][1]/2 + person1[11][1]/2


                    trans_foot_1 = M1@(front_x_1 , front_y_1 , 1)
                    trans_foot_1 = trans_foot_1/trans_foot_1[2]
                    trans_x_1 = trans_foot_1[0]
                    trans_y_1 = trans_foot_1[1]
                    
                    trans_right_1 = M1@(right_x_1 , right_y_1 , 1)
                    trans_right_1 = trans_right_1/trans_right_1[2]
                    tr_x_1 = trans_right_1[0]
                    tr_y_1 = trans_right_1[1]

                    trans_left_1 = M1@(left_x_1 , left_y_1 , 1)
                    trans_left_1 = trans_left_1/trans_left_1[2]
                    tl_x_1 = trans_left_1[0]
                    tl_y_1 = trans_left_1[1]
                    
                
                    if poly_1.contains(Point(front_x_1 , front_y_1)) == True:

                    #if xy_1[0] < 446 and xy_1[0] > 178 and xy_1[1] > 270 and xy_1[1] < 408: #before1 = np.float32([[346, 623],[915,401],[714, 155],[169,92]])
                        pts1 = np.array([[tl_x_1,tl_y_1],[tr_x_1,tr_y_1],[trans_x_1,trans_y_1]], np.int32)
                        ROI_image = cv2.circle(ROI_image,(int(trans_x_1),int(trans_y_1)), 5, (0,0,255), -1)
                        ROI_image2 = cv2.polylines(ROI_image2, [pts1], True, (0,0,255), 1 )
                        ROI_image2 = cv2.circle(ROI_image2,(int(trans_x_1),int(trans_y_1)), 2, (0,0,0), -1)


      
        #[195,303],[100,500],[943,713],[981,175]
        poly_list_2 = [(195,303),(100,500),(943,713),(981,175)]
        poly_2 = Polygon(poly_list_2)
        for b,person2  in enumerate(camera_2):
            for w,box2 in enumerate(boxes_2):
                if box2[4] > 0.9 and b == w:
                
                    left_x_2 = person2[7][0]
                    left_y_2 = person2[7][1]
                    right_x_2 = person2[8][0]
                    right_y_2 = person2[8][1]
                    front_x_2 = person2[10][0]/2 + person2[11][0]/2
                    front_y_2 = person2[10][1]/2 + person2[11][1]/2


                    trans_foot_2 = M2@(front_x_2 , front_y_2 , 1)
                    trans_foot_2 = trans_foot_2/trans_foot_2[2]
                    trans_x_2 = trans_foot_2[0]
                    trans_y_2 = trans_foot_2[1]


                    trans_right_2 = M2@(right_x_2 , right_y_2 , 1)
                    trans_right_2 = trans_right_2/trans_right_2[2]
                    tr_x_2 = trans_right_2[0]
                    tr_y_2 = trans_right_2[1]

                    trans_left_2 = M2@(left_x_2 , left_y_2 , 1)
                    trans_left_2 = trans_left_2/trans_left_2[2]
                    tl_x_2 = trans_left_2[0]
                    tl_y_2 = trans_left_2[1]
                
                    
                    if poly_2.contains(Point(front_x_2 , front_y_2)) == True:

                    #if xy_1[0] < 446 and xy_1[0] > 178 and xy_1[1] > 270 and xy_1[1] < 408: #before1 = np.float32([[346, 623],[915,401],[714, 155],[169,92]])
                        pts2 = np.array([[tl_x_2,tl_y_2],[tr_x_2,tr_y_2],[trans_x_2,trans_y_2]], np.int32)
                        ROI_image = cv2.circle(ROI_image,(int(trans_x_2),int(trans_y_2)), 5, (0,255,0), -1)
                        ROI_image2 = cv2.polylines(ROI_image2, [pts2], True, (0,255,0), 1 )
                        ROI_image2 = cv2.circle(ROI_image2,(int(trans_x_2),int(trans_y_2)), 2, (0,0,0), -1)

        
        
        #[304,577],[730,719],[933,130],[530,200]
        poly_list_3 = [(304,577),(730,719),(933,130),(530,200)]
        poly_3 = Polygon(poly_list_3)
        for c,person3  in enumerate(camera_3):
            for e,box3 in enumerate(boxes_3):
                if box3[4] > 0.9 and c == e:
                    
                    left_x_3 = person3[7][0]
                    left_y_3 = person3[7][1]
                    right_x_3 = person3[8][0]
                    right_y_3 = person3[8][1]
                    front_x_3 = person3[10][0]/2 + person3[11][0]/2
                    front_y_3 = person3[10][1]/2 + person3[11][1]/2


                    trans_foot_3 = M3@(front_x_3 , front_y_3 , 1)
                    trans_foot_3 = trans_foot_3/trans_foot_3[2]
                    trans_x_3 = trans_foot_3[0]
                    trans_y_3 = trans_foot_3[1]

                    trans_right_3 = M3@(right_x_3 , right_y_3 , 1)
                    trans_right_3 = trans_right_3/trans_right_3[2]
                    tr_x_3 = trans_right_3[0]
                    tr_y_3 = trans_right_3[1]

                    trans_left_3 = M3@(left_x_3 , left_y_3 , 1)
                    trans_left_3 = trans_left_3/trans_left_3[2]
                    tl_x_3 = trans_left_3[0]
                    tl_y_3 = trans_left_3[1]
                
                    
                    if poly_3.contains(Point(front_x_3 , front_y_3)) == True:

                    #if xy_1[0] < 446 and xy_1[0] > 178 and xy_1[1] > 270 and xy_1[1] < 408: #before1 = np.float32([[346, 623],[915,401],[714, 155],[169,92]])
                        pts3 = np.array([[tl_x_3,tl_y_3],[tr_x_3,tr_y_3],[trans_x_3,trans_y_3]], np.int32)
                        ROI_image = cv2.circle(ROI_image,(int(trans_x_3),int(trans_y_3)), 5, (255,0,0), -1)
                        ROI_image2 = cv2.polylines(ROI_image2, [pts3], True, (255,0,0), 1)
                        ROI_image2 = cv2.circle(ROI_image2,(int(trans_x_3),int(trans_y_3)), 2, (0,0,0), -1)
                

        resize_frame1 = cv2.resize(frame1, (320, 180))
        resize_frame2 = cv2.resize(frame2, (320, 180))
        resize_frame3 = cv2.resize(frame3, (320, 180))
        resize_ROI_image = cv2.resize(ROI_image, (960,540))
        

        img_con = cv2.vconcat([resize_frame1, resize_frame2,resize_frame3])
        img_hcon = cv2.hconcat([img_con, resize_ROI_image])
        

            
            
        cv2.imshow('mapping', img_hcon)
        cv2.imshow('vector', ROI_image2)
        
        
        # 영상을 저장한다.
        out1.write(frame1)
        out2.write(frame2)
        out3.write(frame3)
        out4.write(img_hcon)
        out5.write(ROI_image2)
        
        # 1ms뒤에 뒤에 코드 실행해준다.
        k = cv2.waitKey(1) & 0xff
        #키보드 esc 누르면 종료된다.
        if k == 27:
            break

    animation = camera.animate()    
    animation.save('ani.gif', writer='PillowWriter', fps=2)
    
    video_capture1.release()  # cap 객체 해제
    video_capture2.release()  # cap 객체 해제
    video_capture3.release()  # cap 객체 해제
    out1.release()  # out 객체 해제
    out2.release()  # out 객체 해제
    out3.release()  # out 객체 해제
    out4.release()  # out 객체 해제
    out5.release()  # out 객체 해제
    cv2.destroyAllWindows()

if __name__ == "__main__":
    writeVideo()
# Out:
# []
# [[[  644.4     -1011.4      8114.4    ]
#   [  567.6      -988.2      8162.4    ]
#   [  597.3      -926.8      8093.6    ]
#   [  694.4     -1084.6      8088.     ]
#   [  467.5      -799.3      8292.     ]
#   [  543.55     -725.8      8154.4    ]
#   [  821.1     -1172.6      8094.4    ]
#   [  295.9      -600.4      8276.8    ]
#   [  236.675    -567.95     8244.     ]
#   [  867.2     -1168.8      8130.4    ]
#   [  286.12265  -547.25     8360.     ]
#   [  222.1875   -507.55     8286.4    ]
#   [ 1044.8     -1251.2      8135.2    ]
#   [  935.2     -1274.2      8163.2    ]
#   [  994.8     -1174.6      8081.6    ]
#   [ 1090.6     -1247.4      8171.2    ]
#   [  934.9     -1312.6      8225.6    ]
#   [ 1053.4     -1096.       8059.2    ]
#   [  771.3     -1247.1      8346.4    ]
#   [ 1017.7      -848.3      8083.2    ]
#   [  859.2     -1091.8      8452.8    ]
#   [ 1015.       -806.2      8225.6    ]
#   [  886.6     -1046.3      8494.4    ]
#   [ 1031.3      -789.2      8284.8    ]]]
# [[[ 644.4     8114.4     1011.4    ]
#   [ 567.6     8162.4      988.2    ]
#   [ 597.3     8093.6      926.8    ]
#   [ 694.4     8088.      1084.6    ]
#   [ 467.5     8292.       799.3    ]
#   [ 543.55    8154.4      725.8    ]
#   [ 821.1     8094.4     1172.6    ]
#   [ 295.9     8276.8      600.4    ]
#   [ 236.675   8244.       567.95   ]
#   [ 867.2     8130.4     1168.8    ]
#   [ 286.12265 8360.       547.25   ]
#   [ 222.1875  8286.4      507.55   ]
#   [1044.8     8135.2     1251.2    ]
#   [ 935.2     8163.2     1274.2    ]
#   [ 994.8     8081.6     1174.6    ]
#   [1090.6     8171.2     1247.4    ]
#   [ 934.9     8225.6     1312.6    ]
#   [1053.4     8059.2     1096.     ]
#   [ 771.3     8346.4     1247.1    ]
#   [1017.7     8083.2      848.3    ]
#   [ 859.2     8452.8     1091.8    ]
#   [1015.      8225.6      806.2    ]
#   [ 886.6     8494.4     1046.3    ]
#   [1031.3     8284.8      789.2    ]]]
# []
# []
# []
# [[[  606.2      -998.7      7867.2    ]
#   [  535.8      -975.3      7905.6    ]
#   [  553.65     -923.2      7838.4    ]
#   [  654.8     -1065.8      7843.2    ]
#   [  427.15     -808.9      7984.     ]
#   [  453.55     -762.9      7884.     ]
#   [  776.1     -1129.6      7854.4    ]
#   [  214.425    -545.25     7971.2    ]
#   [  180.5875   -521.05     7956.8    ]
#   [  823.9     -1135.2      7891.2    ]
#   [  183.40625  -503.8      8025.6    ]
#   [  135.35625  -469.9      7973.6    ]
#   [ 1008.8     -1218.4      7905.6    ]
#   [  892.5     -1235.2      7927.2    ]
#   [  957.3     -1140.2      7851.2    ]
#   [ 1054.4     -1219.       7944.8    ]
#   [  892.5     -1274.6      7991.2    ]
#   [ 1017.1     -1065.5      7836.     ]
#   [  723.3     -1229.8      8099.2    ]
#   [  970.7      -838.6      7844.     ]
#   [  779.8     -1094.9      8188.8    ]
#   [  966.9      -779.2      7968.     ]
#   [  805.1     -1056.5      8238.4    ]
#   [  993.7      -755.8      8016.8    ]]]
# [[[ 606.2     7867.2      998.7    ]
#   [ 535.8     7905.6      975.3    ]
#   [ 553.65    7838.4      923.2    ]
#   [ 654.8     7843.2     1065.8    ]
#   [ 427.15    7984.       808.9    ]
#   [ 453.55    7884.       762.9    ]
#   [ 776.1     7854.4     1129.6    ]
#   [ 214.425   7971.2      545.25   ]
#   [ 180.5875  7956.8      521.05   ]
#   [ 823.9     7891.2     1135.2    ]
#   [ 183.40625 8025.6      503.8    ]
#   [ 135.35625 7973.6      469.9    ]
#   [1008.8     7905.6     1218.4    ]
#   [ 892.5     7927.2     1235.2    ]
#   [ 957.3     7851.2     1140.2    ]
#   [1054.4     7944.8     1219.     ]
#   [ 892.5     7991.2     1274.6    ]
#   [1017.1     7836.      1065.5    ]
#   [ 723.3     8099.2     1229.8    ]
#   [ 970.7     7844.       838.6    ]
#   [ 779.8     8188.8     1094.9    ]
#   [ 966.9     7968.       779.2    ]
#   [ 805.1     8238.4     1056.5    ]
#   [ 993.7     8016.8      755.8    ]]]
# []
# []
# []
# []
# []
# []
# []
# []
# [[[  650.9     -1047.7      8222.4    ]
#   [  557.6     -1031.3      8248.     ]
#   [  603.9      -963.1      8203.2    ]
#   [  713.9     -1125.6      8200.     ]
#   [  387.95     -912.4      8304.8    ]
#   [  523.6      -796.8      8275.2    ]
#   [  852.4     -1185.2      8221.6    ]
#   [  175.6      -567.       8271.2    ]
#   [  197.175    -550.95     8316.8    ]
#   [  894.2     -1188.8      8252.8    ]
#   [   80.39687  -558.2      8291.2    ]
#   [  152.       -506.35     8360.     ]
#   [ 1083.6     -1266.6      8266.4    ]
#   [  977.      -1291.2      8281.6    ]
#   [ 1027.4     -1187.8      8223.2    ]
#   [ 1125.4     -1261.2      8308.8    ]
#   [  981.7     -1329.6      8340.8    ]
#   [ 1085.6     -1101.5      8216.     ]
#   [  860.5     -1250.6      8480.     ]
#   [ 1058.2      -864.6      8236.     ]
#   [  947.3     -1089.       8594.4    ]
#   [ 1089.1      -725.2      8361.6    ]
#   [  969.7     -1050.3      8644.     ]
#   [ 1089.1      -702.8      8398.4    ]]]
# [[[ 650.9     8222.4     1047.7    ]
#   [ 557.6     8248.      1031.3    ]
#   [ 603.9     8203.2      963.1    ]
#   [ 713.9     8200.      1125.6    ]
#   [ 387.95    8304.8      912.4    ]
#   [ 523.6     8275.2      796.8    ]
#   [ 852.4     8221.6     1185.2    ]
#   [ 175.6     8271.2      567.     ]
#   [ 197.175   8316.8      550.95   ]
#   [ 894.2     8252.8     1188.8    ]
#   [  80.39687 8291.2      558.2    ]
#   [ 152.      8360.       506.35   ]
#   [1083.6     8266.4     1266.6    ]
#   [ 977.      8281.6     1291.2    ]
#   [1027.4     8223.2     1187.8    ]
#   [1125.4     8308.8     1261.2    ]
#   [ 981.7     8340.8     1329.6    ]
#   [1085.6     8216.      1101.5    ]
#   [ 860.5     8480.      1250.6    ]
#   [1058.2     8236.       864.6    ]
#   [ 947.3     8594.4     1089.     ]
#   [1089.1     8361.6      725.2    ]
#   [ 969.7     8644.      1050.3    ]
#   [1089.1     8398.4      702.8    ]]]
# [[[  652.1    -1057.8     8292.8   ]
#   [  559.     -1040.6     8314.4   ]
#   [  605.4     -975.4     8272.8   ]
#   [  718.5    -1137.      8272.    ]
#   [  384.      -919.8     8356.8   ]
#   [  505.65    -804.2     8336.8   ]
#   [  855.1    -1192.4     8293.6   ]
#   [  173.5375  -590.6     8343.2   ]
#   [  212.35    -569.9     8391.2   ]
#   [  897.2    -1198.6     8328.8   ]
#   [   73.1125  -570.      8368.    ]
#   [  164.7     -518.9     8428.8   ]
#   [ 1090.     -1282.      8346.4   ]
#   [  980.4    -1303.4     8358.4   ]
#   [ 1033.7    -1201.      8301.6   ]
#   [ 1134.2    -1278.      8387.2   ]
#   [  982.3    -1344.      8413.6   ]
#   [ 1092.8    -1117.8     8296.    ]
#   [  839.5    -1282.4     8547.2   ]
#   [ 1069.6     -872.6     8322.4   ]
#   [  944.6    -1103.9     8680.8   ]
#   [ 1097.9     -734.1     8441.6   ]
#   [  969.4    -1063.3     8740.8   ]
#   [ 1096.4     -711.7     8480.8   ]]]
# [[[ 652.1    8292.8    1057.8   ]
#   [ 559.     8314.4    1040.6   ]
#   [ 605.4    8272.8     975.4   ]
#   [ 718.5    8272.     1137.    ]
#   [ 384.     8356.8     919.8   ]
#   [ 505.65   8336.8     804.2   ]
#   [ 855.1    8293.6    1192.4   ]
#   [ 173.5375 8343.2     590.6   ]
#   [ 212.35   8391.2     569.9   ]
#   [ 897.2    8328.8    1198.6   ]
#   [  73.1125 8368.      570.    ]
#   [ 164.7    8428.8     518.9   ]
#   [1090.     8346.4    1282.    ]
#   [ 980.4    8358.4    1303.4   ]
#   [1033.7    8301.6    1201.    ]
#   [1134.2    8387.2    1278.    ]
#   [ 982.3    8413.6    1344.    ]
#   [1092.8    8296.     1117.8   ]
#   [ 839.5    8547.2    1282.4   ]
#   [1069.6    8322.4     872.6   ]
#   [ 944.6    8680.8    1103.9   ]
#   [1097.9    8441.6     734.1   ]
#   [ 969.4    8740.8    1063.3   ]
#   [1096.4    8480.8     711.7   ]]]
# []
# []
# []
# [[[  644.2     -1039.5      8156.     ]
#   [  547.8     -1028.1      8176.     ]
#   [  600.5      -953.2      8137.6    ]
#   [  710.1     -1115.       8137.6    ]
#   [  380.85     -898.8      8247.2    ]
#   [  499.9      -791.1      8220.     ]
#   [  843.9     -1170.       8170.4    ]
#   [  151.9625   -561.2      8216.     ]
#   [  181.225    -545.7      8269.6    ]
#   [  885.7     -1174.8      8204.8    ]
#   [   41.35625  -551.9      8252.8    ]
#   [  141.4625   -510.75     8315.2    ]
#   [ 1077.2     -1255.4      8230.4    ]
#   [  967.7     -1276.8      8240.8    ]
#   [ 1022.1     -1175.4      8184.8    ]
#   [ 1119.6     -1253.6      8276.8    ]
#   [  970.      -1312.4      8296.8    ]
#   [ 1083.3     -1088.       8183.2    ]
#   [  847.8     -1216.4      8443.2    ]
#   [ 1049.7      -851.2      8193.6    ]
#   [  961.8     -1035.1      8562.4    ]
#   [ 1093.5      -711.3      8310.4    ]
#   [  991.6      -998.7      8621.6    ]
#   [ 1097.1      -682.8      8358.4    ]]]
# [[[ 644.2     8156.      1039.5    ]
#   [ 547.8     8176.      1028.1    ]
#   [ 600.5     8137.6      953.2    ]
#   [ 710.1     8137.6     1115.     ]
#   [ 380.85    8247.2      898.8    ]
#   [ 499.9     8220.       791.1    ]
#   [ 843.9     8170.4     1170.     ]
#   [ 151.9625  8216.       561.2    ]
#   [ 181.225   8269.6      545.7    ]
#   [ 885.7     8204.8     1174.8    ]
#   [  41.35625 8252.8      551.9    ]
#   [ 141.4625  8315.2      510.75   ]
#   [1077.2     8230.4     1255.4    ]
#   [ 967.7     8240.8     1276.8    ]
#   [1022.1     8184.8     1175.4    ]
#   [1119.6     8276.8     1253.6    ]
#   [ 970.      8296.8     1312.4    ]
#   [1083.3     8183.2     1088.     ]
#   [ 847.8     8443.2     1216.4    ]
#   [1049.7     8193.6      851.2    ]
#   [ 961.8     8562.4     1035.1    ]
#   [1093.5     8310.4      711.3    ]
#   [ 991.6     8621.6      998.7    ]
#   [1097.1     8358.4      682.8    ]]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [[[  633.1      -1028.8       8076.8     ]
#   [  546.1      -1005.3       8104.8     ]
#   [  580.8       -956.2       8061.6     ]
#   [  697.8      -1098.8       8052.      ]
#   [  365.5       -850.6       8187.2     ]
#   [  449.6       -760.7       8130.4     ]
#   [  829.2      -1161.6       8073.6     ]
#   [  140.63126   -575.7       8236.8     ]
#   [  151.78125   -540.65      8239.2     ]
#   [  869.5      -1167.2       8105.6     ]
#   [   44.7375    -570.8       8290.4     ]
#   [  117.100784  -507.45      8277.6     ]
#   [ 1053.6      -1247.6       8117.6     ]
#   [  960.8      -1251.2       8139.2     ]
#   [  985.8      -1184.        8074.4     ]
#   [ 1097.4      -1246.2       8156.8     ]
#   [  981.       -1271.        8189.6     ]
#   [ 1026.4      -1124.2       8069.6     ]
#   [  882.4      -1147.1       8327.2     ]
#   [  968.5       -969.6       8099.2     ]
#   [  993.3      -1031.2       8430.4     ]
#   [ 1009.9       -828.5       8214.4     ]
#   [ 1019.6      -1008.6       8474.4     ]
#   [ 1010.9       -803.9       8244.      ]]]
# [[[ 633.1      8076.8      1028.8     ]
#   [ 546.1      8104.8      1005.3     ]
#   [ 580.8      8061.6       956.2     ]
#   [ 697.8      8052.       1098.8     ]
#   [ 365.5      8187.2       850.6     ]
#   [ 449.6      8130.4       760.7     ]
#   [ 829.2      8073.6      1161.6     ]
#   [ 140.63126  8236.8       575.7     ]
#   [ 151.78125  8239.2       540.65    ]
#   [ 869.5      8105.6      1167.2     ]
#   [  44.7375   8290.4       570.8     ]
#   [ 117.100784 8277.6       507.45    ]
#   [1053.6      8117.6      1247.6     ]
#   [ 960.8      8139.2      1251.2     ]
#   [ 985.8      8074.4      1184.      ]
#   [1097.4      8156.8      1246.2     ]
#   [ 981.       8189.6      1271.      ]
#   [1026.4      8069.6      1124.2     ]
#   [ 882.4      8327.2      1147.1     ]
#   [ 968.5      8099.2       969.6     ]
#   [ 993.3      8430.4      1031.2     ]
#   [1009.9      8214.4       828.5     ]
#   [1019.6      8474.4      1008.6     ]
#   [1010.9      8244.        803.9     ]]]
# [[[  619.8     -1014.6      7963.2    ]
#   [  531.25     -995.1      7989.6    ]
#   [  568.6      -940.       7944.     ]
#   [  683.6     -1083.8      7942.4    ]
#   [  348.15     -841.1      8063.2    ]
#   [  431.7      -759.       8003.2    ]
#   [  815.4     -1143.8      7965.6    ]
#   [  133.10625  -567.3      8080.8    ]
#   [  130.775    -531.95     8081.6    ]
#   [  856.4     -1149.6      7996.8    ]
#   [   29.33125  -563.6      8120.8    ]
#   [   81.96875  -502.3      8104.8    ]
#   [ 1042.5     -1227.8      8016.8    ]
#   [  944.7     -1237.6      8031.2    ]
#   [  977.9     -1158.8      7968.8    ]
#   [ 1084.7     -1227.       8053.6    ]
#   [  959.1     -1265.2      8087.2    ]
#   [ 1023.7     -1089.       7962.4    ]
#   [  844.5     -1152.       8223.2    ]
#   [  975.7      -897.2      7992.8    ]
#   [  928.3     -1043.2      8310.4    ]
#   [  986.5      -802.5      8109.6    ]
#   [  945.8     -1024.6      8356.8    ]
#   [  987.6      -786.7      8144.8    ]]]
# [[[ 619.8     7963.2     1014.6    ]
#   [ 531.25    7989.6      995.1    ]
#   [ 568.6     7944.       940.     ]
#   [ 683.6     7942.4     1083.8    ]
#   [ 348.15    8063.2      841.1    ]
#   [ 431.7     8003.2      759.     ]
#   [ 815.4     7965.6     1143.8    ]
#   [ 133.10625 8080.8      567.3    ]
#   [ 130.775   8081.6      531.95   ]
#   [ 856.4     7996.8     1149.6    ]
#   [  29.33125 8120.8      563.6    ]
#   [  81.96875 8104.8      502.3    ]
#   [1042.5     8016.8     1227.8    ]
#   [ 944.7     8031.2     1237.6    ]
#   [ 977.9     7968.8     1158.8    ]
#   [1084.7     8053.6     1227.     ]
#   [ 959.1     8087.2     1265.2    ]
#   [1023.7     7962.4     1089.     ]
#   [ 844.5     8223.2     1152.     ]
#   [ 975.7     7992.8      897.2    ]
#   [ 928.3     8310.4     1043.2    ]
#   [ 986.5     8109.6      802.5    ]
#   [ 945.8     8356.8     1024.6    ]
#   [ 987.6     8144.8      786.7    ]]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [[[  618.4     -1028.4      8028.     ]
#   [  528.2     -1007.5      8060.     ]
#   [  570.15     -951.9      8004.     ]
#   [  682.4     -1103.       8004.8    ]
#   [  349.9      -842.7      8152.     ]
#   [  457.35     -751.6      8090.4    ]
#   [  814.6     -1162.6      8034.4    ]
#   [  140.90547  -590.7      8152.     ]
#   [  145.4875   -529.       8180.     ]
#   [  859.      -1167.6      8067.2    ]
#   [   35.7875   -574.6      8212.     ]
#   [  107.25105  -481.85     8230.4    ]
#   [ 1048.4     -1249.       8085.6    ]
#   [  947.      -1262.       8101.6    ]
#   [  985.4     -1178.2      8036.8    ]
#   [ 1091.      -1241.6      8123.2    ]
#   [  959.7     -1294.       8159.2    ]
#   [ 1041.9     -1102.8      8029.6    ]
#   [  842.2     -1214.8      8293.6    ]
#   [ 1017.2      -858.4      8048.     ]
#   [  949.5     -1045.6      8384.8    ]
#   [ 1093.4      -716.4      8170.4    ]
#   [  981.5     -1004.6      8430.4    ]
#   [ 1106.8      -702.       8212.     ]]]
# [[[ 618.4     8028.      1028.4    ]
#   [ 528.2     8060.      1007.5    ]
#   [ 570.15    8004.       951.9    ]
#   [ 682.4     8004.8     1103.     ]
#   [ 349.9     8152.       842.7    ]
#   [ 457.35    8090.4      751.6    ]
#   [ 814.6     8034.4     1162.6    ]
#   [ 140.90547 8152.       590.7    ]
#   [ 145.4875  8180.       529.     ]
#   [ 859.      8067.2     1167.6    ]
#   [  35.7875  8212.       574.6    ]
#   [ 107.25105 8230.4      481.85   ]
#   [1048.4     8085.6     1249.     ]
#   [ 947.      8101.6     1262.     ]
#   [ 985.4     8036.8     1178.2    ]
#   [1091.      8123.2     1241.6    ]
#   [ 959.7     8159.2     1294.     ]
#   [1041.9     8029.6     1102.8    ]
#   [ 842.2     8293.6     1214.8    ]
#   [1017.2     8048.       858.4    ]
#   [ 949.5     8384.8     1045.6    ]
#   [1093.4     8170.4      716.4    ]
#   [ 981.5     8430.4     1004.6    ]
#   [1106.8     8212.       702.     ]]]
# [[[  621.      -1042.5      8079.2    ]
#   [  532.3     -1021.2      8107.2    ]
#   [  568.3      -968.6      8057.6    ]
#   [  684.3     -1112.6      8056.     ]
#   [  371.6      -836.2      8200.     ]
#   [  443.15     -761.1      8116.     ]
#   [  821.7     -1166.6      8080.     ]
#   [  144.59375  -572.5      8208.     ]
#   [  125.9875   -532.2      8208.8    ]
#   [  865.6     -1173.4      8112.     ]
#   [   58.4625   -568.6      8249.6    ]
#   [   86.9543   -487.75     8241.6    ]
#   [ 1054.8     -1253.4      8124.8    ]
#   [  952.9     -1265.8      8147.2    ]
#   [  992.      -1181.8      8079.2    ]
#   [ 1099.4     -1250.2      8163.2    ]
#   [  963.7     -1293.4      8200.     ]
#   [ 1047.2     -1105.6      8065.6    ]
#   [  862.6     -1207.9      8334.4    ]
#   [ 1021.4      -854.3      8088.     ]
#   [  951.      -1064.7      8440.     ]
#   [ 1087.8      -720.5      8208.     ]
#   [  975.4     -1029.5      8492.8    ]
#   [ 1099.8      -708.       8245.6    ]]]
# [[[ 621.      8079.2     1042.5    ]
#   [ 532.3     8107.2     1021.2    ]
#   [ 568.3     8057.6      968.6    ]
#   [ 684.3     8056.      1112.6    ]
#   [ 371.6     8200.       836.2    ]
#   [ 443.15    8116.       761.1    ]
#   [ 821.7     8080.      1166.6    ]
#   [ 144.59375 8208.       572.5    ]
#   [ 125.9875  8208.8      532.2    ]
#   [ 865.6     8112.      1173.4    ]
#   [  58.4625  8249.6      568.6    ]
#   [  86.9543  8241.6      487.75   ]
#   [1054.8     8124.8     1253.4    ]
#   [ 952.9     8147.2     1265.8    ]
#   [ 992.      8079.2     1181.8    ]
#   [1099.4     8163.2     1250.2    ]
#   [ 963.7     8200.      1293.4    ]
#   [1047.2     8065.6     1105.6    ]
#   [ 862.6     8334.4     1207.9    ]
#   [1021.4     8088.       854.3    ]
#   [ 951.      8440.      1064.7    ]
#   [1087.8     8208.       720.5    ]
#   [ 975.4     8492.8     1029.5    ]
#   [1099.8     8245.6      708.     ]]]
# []
# [[[  626.6      -1021.        8052.      ]
#   [  537.8       -997.        8079.2     ]
#   [  576.8       -945.5       8028.8     ]
#   [  687.7      -1093.9       8032.      ]
#   [  376.65      -829.3       8144.8     ]
#   [  442.15      -754.3       8083.2     ]
#   [  824.1      -1159.        8059.2     ]
#   [  146.825     -563.45      8141.6     ]
#   [  123.29375   -520.05      8156.8     ]
#   [  868.       -1165.4       8092.      ]
#   [   51.265625  -553.95      8184.8     ]
#   [   97.171875  -481.65      8179.2     ]
#   [ 1050.6      -1242.2       8100.8     ]
#   [  948.6      -1259.4       8122.4     ]
#   [  990.3      -1167.4       8059.2     ]
#   [ 1097.6      -1242.        8143.2     ]
#   [  958.       -1296.        8180.      ]
#   [ 1042.9      -1086.        8051.2     ]
#   [  852.4      -1216.7       8316.8     ]
#   [ 1016.2       -853.7       8080.8     ]
#   [  963.3      -1050.3       8416.      ]
#   [ 1078.8       -731.9       8217.6     ]
#   [  994.2      -1012.        8464.8     ]
#   [ 1090.9       -712.9       8259.2     ]]]
# [[[ 626.6      8052.       1021.      ]
#   [ 537.8      8079.2       997.      ]
#   [ 576.8      8028.8       945.5     ]
#   [ 687.7      8032.       1093.9     ]
#   [ 376.65     8144.8       829.3     ]
#   [ 442.15     8083.2       754.3     ]
#   [ 824.1      8059.2      1159.      ]
#   [ 146.825    8141.6       563.45    ]
#   [ 123.29375  8156.8       520.05    ]
#   [ 868.       8092.       1165.4     ]
#   [  51.265625 8184.8       553.95    ]
#   [  97.171875 8179.2       481.65    ]
#   [1050.6      8100.8      1242.2     ]
#   [ 948.6      8122.4      1259.4     ]
#   [ 990.3      8059.2      1167.4     ]
#   [1097.6      8143.2      1242.      ]
#   [ 958.       8180.       1296.      ]
#   [1042.9      8051.2      1086.      ]
#   [ 852.4      8316.8      1216.7     ]
#   [1016.2      8080.8       853.7     ]
#   [ 963.3      8416.       1050.3     ]
#   [1078.8      8217.6       731.9     ]
#   [ 994.2      8464.8      1012.      ]
#   [1090.9      8259.2       712.9     ]]]
# []
# []
# []
# []
# []
# []
# []
# MovieWriter PillowWriter unavailable; using Pillow instead.
# []
