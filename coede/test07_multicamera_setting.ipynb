# %% [markdown]
# ## **1.카메라 연결 및 영상 저장(RTSP이용)**

# %%
#카메라 3대를 이용하여 저장하기

import cv2
import datetime
import os


def writeVideo():
    #현재시간 가져오기
    currentTime = datetime.datetime.now()
    
    #RTSP를 불러오는 곳
    video_capture1 = cv2.VideoCapture("rtsp://dlwnrud707:dlwnrud707!@192.168.0.80:554/stream1")
    video_capture2 = cv2.VideoCapture("rtsp://dlwnrud707:dlwnrud707!@192.168.0.81:554/stream1")
    video_capture3 = cv2.VideoCapture("rtsp://dlwnrud707:dlwnrud707!@192.168.0.82:554/stream1")
    
    

    # 동영상 크기 변환
    video_capture1.set(cv2.CAP_PROP_FRAME_WIDTH, 640) # 가로
    video_capture1.set(cv2.CAP_PROP_FRAME_HEIGHT, 480) # 세로

    

    '''# 웹캠 설정
    video_capture1.set(3, 640)  # 영상 가로길이 설정
    video_capture1.set(4, 480)  # 영상 세로길이 설정
    print(video_capture1.get(3))'''
    # 웹캠 설정
    video_capture2.set(3, 640)  # 영상 가로길이 설정
    video_capture2.set(4, 480)  # 영상 세로길이 설정
    # 웹캠 설정
    video_capture3.set(3, 640)  # 영상 가로길이 설정
    video_capture3.set(4, 480)  # 영상 세로길이 설정
    
    # 가로 길이 가져오기
    streaming_window_width = int(video_capture1.get(3))
    # 세로 길이 가져오기
    streaming_window_height = int(video_capture1.get(4))  
    
    
    #현재 시간을 '년도 달 일 시간 분 초'로 가져와서 문자열로 생성
    fileName = str(currentTime.strftime('%Y %m %d %H %M %S'))

    #파일 저장하기 위한 변수 선언
    path1 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/peo1.avi'
    #파일 저장하기 위한 변수 선언
    path2 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/peo2.avi'
    #파일 저장하기 위한 변수 선언
    path3 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/peo3.avi'
    
    # DIVX 코덱 적용 # 코덱 종류 # DIVX, XVID, MJPG, X264, WMV1, WMV2
    # 무료 라이선스의 이점이 있는 XVID를 사용
    fourcc = cv2.VideoWriter_fourcc('X', 'V', 'I', 'D')
    fps = 20
    # 비디오 저장
    # cv2.VideoWriter(저장 위치, 코덱, 프레임, (가로, 세로))
    out1 = cv2.VideoWriter(path1, fourcc, fps, (streaming_window_width, streaming_window_height))
    out2 = cv2.VideoWriter(path2, fourcc, fps, (streaming_window_width, streaming_window_height))
    out3 = cv2.VideoWriter(path3, fourcc, fps, (streaming_window_width, streaming_window_height))

    while True:
        ret1, frame1 = video_capture1.read()
        ret2, frame2 = video_capture2.read()
        ret3, frame3 = video_capture3.read()
        # 촬영되는 영상보여준다. 프로그램 상태바 이름은 'streaming video' 로 뜬다.
        cv2.imshow('streaming video1', frame1)
        cv2.imshow('streaming video2', frame2)
        cv2.imshow('streaming video3', frame3)
        
        
        # 영상을 저장한다.
        out1.write(frame1)
        out2.write(frame2)
        out3.write(frame3)
        
        # 1ms뒤에 뒤에 코드 실행해준다.
        k = cv2.waitKey(1) & 0xff
        #키보드 esc 누르면 종료된다.
        if k == 27:
            break
    video_capture1.release()  # cap 객체 해제
    video_capture2.release()  # cap 객체 해제
    video_capture3.release()  # cap 객체 해제
    out1.release()  # out 객체 해제
    out2.release()  # out 객체 해제
    cv2.destroyAllWindows()

if __name__ == "__main__":
    writeVideo()

# %%
#
import cv2
vcap = cv2.VideoCapture(0)
# 원본 동영상 크기 정보
w = vcap.get(cv2.CAP_PROP_FRAME_WIDTH)
h = vcap.get(cv2.CAP_PROP_FRAME_HEIGHT)
print("원본 동영상 너비(가로) : {}, 높이(세로) : {}".format(w, h))
# 동영상 크기 변환
vcap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280) # 가로
vcap.set(cv2.CAP_PROP_FRAME_HEIGHT, 960) # 세로
# 변환된 동영상 크기 정보
w = vcap.get(cv2.CAP_PROP_FRAME_WIDTH)
h = vcap.get(cv2.CAP_PROP_FRAME_HEIGHT)
print("변환된 동영상 너비(가로) : {}, 높이(세로) : {}".format(w, h))

while(1):

    ret, frame = vcap.read()
    cv2.imshow('VIDEO', frame)
    k = cv2.waitKey(1) & 0xff
        #키보드 esc 누르면 종료된다.
    if k == 27:
        break
vcap.release()  # cap 객체 해제
    
cv2.destroyAllWindows()
# Out:
# 원본 동영상 너비(가로) : 640.0, 높이(세로) : 480.0
# 변환된 동영상 너비(가로) : 1280.0, 높이(세로) : 720.0

# %% [markdown]
# ## **2.변환행렬 찾기**

# %%
import numpy as np
import cv2
before1 = np.float32([[346, 623],[915,401],[714, 155],[169,92]])
after1 = np.float32([[196,396],[388,396],[388,267],[196,267]])

M1 = cv2.getPerspectiveTransform(before1,after1)
M1
# Out:
# array([[ 3.04152892e-03,  1.82407614e-01,  1.69835984e+02],
#        [-2.95909021e-01,  7.01168088e-01,  2.40420095e+02],
#        [-9.49469069e-04,  1.25231345e-03,  1.00000000e+00]])

# %%
before2 = np.float32([[942,709],[100,500],[197,306],[983,174]])
after2 = np.float32([[375,90],[375,264],[304,264],[304,90]])

M2 = cv2.getPerspectiveTransform(before2,after2)
M2
# Out:
# array([[ 1.07120712e+01,  1.36392767e+01, -1.87081143e+03],
#        [-4.03074220e-01,  1.88963717e+00,  3.33359281e+03],
#        [ 3.16939051e-02,  2.37680673e-02,  1.00000000e+00]])

# %%
before3 = np.float32([[733,718],[203,542],[415,220],[935,131]])
after3 = np.float32([[439,388],[294,388],[294,272],[439,272]]) 

M3 = cv2.getPerspectiveTransform(before3,after3)
M3
# Out:
# array([[-4.98283981e+01, -4.23554973e+01,  1.51268349e+04],
#        [-2.58291582e+01, -4.78288334e+01,  7.48401733e+03],
#        [-7.93668243e-02, -8.47342837e-02,  1.00000000e+00]])

# %% [markdown]
# ## **3.이미지 맵핑하기(카메라1대)**

# %%
#모델 yolo4
import tensorflow as tf
import os

def download_model(model_type):
    server_prefix = 'https://omnomnom.vision.rwth-aachen.de/data/metrabs'
    model_zippath = tf.keras.utils.get_file(
        origin=f'{server_prefix}/{model_type}.zip',
        extract=True, cache_subdir='models')
    model_path = os.path.join(os.path.dirname(model_zippath), model_type)
    return model_path

model = tf.saved_model.load(download_model('metrabs_rn18_y4'))

# %%
def draw_keypoints(frame,keypoints):
    shaped = np.squeeze(keypoints)
    
    for p in shaped:
        x,y = p
        if x > 0:
            cv2.circle(frame,(int(x),int(y)), 4, (0,255,0), -1)

# %%
def loop_through_people(frame ,keypoints_with):
    for person in keypoints_with:
        draw_keypoints(frame,person)

# %%
# 카메라 1대
cap = cv2.VideoCapture('C:/Users/Leeyourack/jookyoung/video/2.detect_video/peo2.avi')
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
fourcc = cv2.VideoWriter_fourcc(*'DIVX')
out = cv2.VideoWriter('C:/Users/Leeyourack/jookyoung/video/2.detect_video/result2.avi', fourcc, 29, (int(width),int(height)))
ROI_image = cv2.imread('C:/Users/Leeyourack/jookyoung/image/0.ROI_image/pre_image_final.jpg')

while cap.isOpened():
    ret, frame = cap.read() 

    img = frame.copy()

    # prdeiction
    results = model.detect_poses(img, skeleton='smpl_24')
    keypoints_with = results['poses2d'].numpy()

    # render keypoints
    loop_through_people(frame, keypoints_with)
    foot_xy = results['poses2d'].numpy()[:,9]

    
    
    for i, xy in enumerate(foot_xy):
        trans_foot = M2@(xy[0], xy[1], 1)
        trans_foot = trans_foot/trans_foot[2]
        trans_x = trans_foot[0]
        trans_y = trans_foot[1]
        
        
        if trans_x<445 and trans_x>185 and trans_y > 245 and trans_y < 411: #after1 = np.float32([[446, 270],[178,260],[178,405],[444,408]])

        #trans_x < 383 and trans_x > 291 and trans_y > 81 and trans_y < 235: #after2 = np.float32([[291,81],[291,235],[383,235],[383,81]])
        #if trans_x<432 and trans_x>286 and trans_y > 272 and trans_y < 410: #after3 = np.float32([[432,410],[432,272],[286,272],[272,410]])

            ROI_image = cv2.circle(ROI_image,(int(trans_x),int(trans_y)),5,(0,0,255),-1)
    

    cv2.imshow('2D', ROI_image)
    cv2.imshow('detect1',frame)
    out.write(frame)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## **3.이미지 맵핑하기(카메라3대)**

# %%
#카메라 3대 다 찍어줘

import cv2
import datetime
import os
ROI_image = cv2.imread('C:/Users/Leeyourack/jookyoung/image/0.ROI_image/pre_image_final.jpg')


def writeVideo():
    global ROI_image
    #현재시간 가져오기
    currentTime = datetime.datetime.now()
    
    #RTSP를 불러오는 곳
    video_capture1 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test1.avi")
    video_capture2 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test2.avi")
    video_capture3 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test3.avi")
    

    # 웹캠 설정
    video_capture1.set(3, 800)  # 영상 가로길이 설정
    video_capture1.set(4, 600)  # 영상 세로길이 설정
    # 웹캠 설정
    video_capture2.set(3, 800)  # 영상 가로길이 설정
    video_capture2.set(4, 600)  # 영상 세로길이 설정
    # 웹캠 설정
    video_capture3.set(3, 800)  # 영상 가로길이 설정
    video_capture3.set(4, 600)  # 영상 세로길이 설정
    
    # 가로 길이 가져오기
    streaming_window_width = int(video_capture1.get(3))
    # 세로 길이 가져오기
    streaming_window_height = int(video_capture1.get(4))  

   
    
    
    #현재 시간을 '년도 달 일 시간 분 초'로 가져와서 문자열로 생성
    fileName = str(currentTime.strftime('%Y %m %d %H %M %S'))

    #파일 저장하기 위한 변수 선언
    path1 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test1.avi'
    #파일 저장하기 위한 변수 선언
    path2 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test2.avi'
    #파일 저장하기 위한 변수 선언
    path3 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test3.avi'
    #파일 저장하기 위한 변수 선언
    path4 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test4.avi'
    
    # DIVX 코덱 적용 # 코덱 종류 # DIVX, XVID, MJPG, X264, WMV1, WMV2
    # 무료 라이선스의 이점이 있는 XVID를 사용
    fourcc = cv2.VideoWriter_fourcc('X', 'V', 'I', 'D')
    fps = 20
    # 비디오 저장
    # cv2.VideoWriter(저장 위치, 코덱, 프레임, (가로, 세로))
    out1 = cv2.VideoWriter(path1, fourcc, fps, (streaming_window_width, streaming_window_height))
    out2 = cv2.VideoWriter(path2, fourcc, fps, (streaming_window_width, streaming_window_height))
    out3 = cv2.VideoWriter(path3, fourcc, fps, (streaming_window_width, streaming_window_height))
    out4 = cv2.VideoWriter(path4, fourcc, fps, (1280, 540))

    while True:
        ret1, frame1 = video_capture1.read()
        ret2, frame2 = video_capture2.read()
        ret3, frame3 = video_capture3.read()
        
        img1 = frame1.copy()
        img2 = frame2.copy()
        img3 = frame3.copy()

        results1 = model.detect_poses(img1, skeleton='smpl_24')
        keypoints_with1 = results1['poses2d'].numpy()
        results2 = model.detect_poses(img2, skeleton='smpl_24')
        keypoints_with2 = results2['poses2d'].numpy()
        results3 = model.detect_poses(img3, skeleton='smpl_24')
        keypoints_with3 = results3['poses2d'].numpy()

        loop_through_people(frame1, keypoints_with1)
        foot_xy1 = results1['poses2d'].numpy()[:,9]

        loop_through_people(frame2, keypoints_with2)
        foot_xy2 = results2['poses2d'].numpy()[:,9]

        loop_through_people(frame3, keypoints_with3)
        foot_xy3 = results3['poses2d'].numpy()[:,9]

        for a, xy_1 in enumerate(foot_xy1):
            trans_foot_1 = M1@(xy_1[0], xy_1[1], 1)
            trans_foot_1 = trans_foot_1/trans_foot_1[2]
            trans_x_1 = trans_foot_1[0]
            trans_y_1 = trans_foot_1[1]
            
            
            #if trans_x_1 < 446 and trans_x_1 > 178 and trans_y_1 > 270 and trans_y_1 < 408: #after1 = np.float32([[446, 270],[178,260],[178,405],[444,408]])
         
            ROI_image = cv2.circle(ROI_image,(int(trans_x_1),int(trans_y_1)), 3, (0,0,255), -1)
        
        
        for b, xy_2 in enumerate(foot_xy2):
            trans_foot_2 = M2@(xy_2[0], xy_2[1], 1)
            trans_foot_2 = trans_foot_2/trans_foot_2[2]
            trans_x_2 = trans_foot_2[0]
            trans_y_2 = trans_foot_2[1]
            
            
         
            #if trans_x_2 < 383 and trans_x_2 > 291 and trans_y_2 > 81 and trans_y_2 < 235: #after2 = np.float32([[291,81],[291,235],[383,235],[383,81]])
            
            ROI_image = cv2.circle(ROI_image,(int(trans_x_2),int(trans_y_2)), 3, (0,255,0), -1)

        
        for c, xy_3 in enumerate(foot_xy3):
            trans_foot_3 = M3@(xy_3[0], xy_3[1], 1)
            trans_foot_3 = trans_foot_3/trans_foot_3[2]
            trans_x_3 = trans_foot_3[0]
            trans_y_3 = trans_foot_3[1]
            
            
           
            #if trans_x_3 < 446 and trans_x_3 > 177 and trans_y_3 > 270 and trans_y_3 < 400: #after3 = np.float32([[446,270],[177,270],[177,400],[446,400]]) 

            ROI_image = cv2.circle(ROI_image,(int(trans_x_3),int(trans_y_3)), 3, (255,0,0), -1)

        resize_frame1 = cv2.resize(frame1, (320, 180))
        resize_frame2 = cv2.resize(frame2, (320, 180))
        resize_frame3 = cv2.resize(frame3, (320, 180))
        resize_ROI_image = cv2.resize(ROI_image, (960,540) )
        

        img_con = cv2.vconcat([resize_frame1, resize_frame2,resize_frame3])
        img_hcon = cv2.hconcat([img_con, resize_ROI_image])
    

        
        
        cv2.imshow('mapping', img_hcon)
        
        
        # 영상을 저장한다.
        out1.write(frame1)
        out2.write(frame2)
        out3.write(frame3)
        out4.write(img_hcon)
        
        # 1ms뒤에 뒤에 코드 실행해준다.
        k = cv2.waitKey(1) & 0xff
        #키보드 esc 누르면 종료된다.
        if k == 27:
            break
    video_capture1.release()  # cap 객체 해제
    video_capture2.release()  # cap 객체 해제
    video_capture3.release()  # cap 객체 해제
    out1.release()  # out 객체 해제
    out2.release()  # out 객체 해제
    out3.release()  # out 객체 해제
    out4.release()  # out 객체 해제
    cv2.destroyAllWindows()

if __name__ == "__main__":
    writeVideo()

# %%
#카메라 3대  원하는 영역에서 검출된 발(9번)만 mapping

import cv2
import datetime
import os

from shapely.geometry import Point
from shapely.geometry.polygon import Polygon


ROI_image = cv2.imread('C:/Users/Leeyourack/jookyoung/image/0.ROI_image/pre_image_final.jpg')

def writeVideo():
    global ROI_image
    #현재시간 가져오기
    currentTime = datetime.datetime.now()
    
    #RTSP를 불러오는 곳
    video_capture1 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test1.avi")
    video_capture2 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test2.avi")
    video_capture3 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test3.avi")
    

    # 웹캠 설정
    video_capture1.set(3, 800)  # 영상 가로길이 설정
    video_capture1.set(4, 600)  # 영상 세로길이 설정
    # 웹캠 설정
    video_capture2.set(3, 800)  # 영상 가로길이 설정
    video_capture2.set(4, 600)  # 영상 세로길이 설정
    # 웹캠 설정
    video_capture3.set(3, 800)  # 영상 가로길이 설정
    video_capture3.set(4, 600)  # 영상 세로길이 설정
    
    # 가로 길이 가져오기
    streaming_window_width = int(video_capture1.get(3))
    # 세로 길이 가져오기
    streaming_window_height = int(video_capture1.get(4))  

   
    
    
    #현재 시간을 '년도 달 일 시간 분 초'로 가져와서 문자열로 생성
    fileName = str(currentTime.strftime('%Y %m %d %H %M %S'))

    #파일 저장하기 위한 변수 선언
    path1 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test1.avi'
    #파일 저장하기 위한 변수 선언
    path2 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test2.avi'
    #파일 저장하기 위한 변수 선언
    path3 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test3.avi'
    #파일 저장하기 위한 변수 선언
    path4 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test4-2.avi'
    
    # DIVX 코덱 적용 # 코덱 종류 # DIVX, XVID, MJPG, X264, WMV1, WMV2
    # 무료 라이선스의 이점이 있는 XVID를 사용
    fourcc = cv2.VideoWriter_fourcc('X', 'V', 'I', 'D')
    fps = 20
    # 비디오 저장
    # cv2.VideoWriter(저장 위치, 코덱, 프레임, (가로, 세로))
    out1 = cv2.VideoWriter(path1, fourcc, fps, (streaming_window_width, streaming_window_height))
    out2 = cv2.VideoWriter(path2, fourcc, fps, (streaming_window_width, streaming_window_height))
    out3 = cv2.VideoWriter(path3, fourcc, fps, (streaming_window_width, streaming_window_height))
    out4 = cv2.VideoWriter(path4, fourcc, fps, (1280, 540))

    while True:
        ret1, frame1 = video_capture1.read()
        ret2, frame2 = video_capture2.read()
        ret3, frame3 = video_capture3.read()
        
        img1 = frame1.copy()
        img2 = frame2.copy()
        img3 = frame3.copy()

        results1 = model.detect_poses(img1, skeleton='smpl_24')
        keypoints_with1 = results1['poses2d'].numpy()
        results2 = model.detect_poses(img2, skeleton='smpl_24')
        keypoints_with2 = results2['poses2d'].numpy()
        results3 = model.detect_poses(img3, skeleton='smpl_24')
        keypoints_with3 = results3['poses2d'].numpy()

        loop_through_people(frame1, keypoints_with1)
        foot_xy1 = results1['poses2d'].numpy()[:,9]

        loop_through_people(frame2, keypoints_with2)
        foot_xy2 = results2['poses2d'].numpy()[:,9]

        loop_through_people(frame3, keypoints_with3)
        foot_xy3 = results3['poses2d'].numpy()[:,9]
        
        poly_list_1 = [(346, 623), (915,401), (714, 155), (169,92)]
        poly_1 = Polygon(poly_list_1)
        for a, xy_1 in enumerate(foot_xy1):
            trans_foot_1 = M1@(xy_1[0], xy_1[1], 1)
            trans_foot_1 = trans_foot_1/trans_foot_1[2]
            trans_x_1 = trans_foot_1[0]
            trans_y_1 = trans_foot_1[1]
            print(xy_1)
            
            if poly_1.contains(Point(xy_1[0], xy_1[1])) == True:

            #if xy_1[0] < 446 and xy_1[0] > 178 and xy_1[1] > 270 and xy_1[1] < 408: #before1 = np.float32([[346, 623],[915,401],[714, 155],[169,92]])
         
                ROI_image = cv2.circle(ROI_image,(int(trans_x_1),int(trans_y_1)), 3, (0,0,255), -1)
        
        poly_list_2 = [(942,709), (100,500), (197,306), (983,174)]
        poly_2 = Polygon(poly_list_2)
        for b, xy_2 in enumerate(foot_xy2):
            trans_foot_2 = M2@(xy_2[0], xy_2[1], 1)
            trans_foot_2 = trans_foot_2/trans_foot_2[2]
            trans_x_2 = trans_foot_2[0]
            trans_y_2 = trans_foot_2[1]
            
            
            if poly_2.contains(Point(xy_2[0], xy_2[1])) == True:
            #if xy_2[0] < 383 and xy_2[0] > 291 and xy_2[1] > 81 and xy_2[1] < 235: #before2 = np.float32([[942,709],[100,500],[197,306],[983,174]])
            
                ROI_image = cv2.circle(ROI_image,(int(trans_x_2),int(trans_y_2)), 3, (0,255,0), -1)

        poly_list_3 = [(733,718), (203,542), (415,220), (935,131)]
        poly_3 = Polygon(poly_list_3)
        for c, xy_3 in enumerate(foot_xy3):
            trans_foot_3 = M3@(xy_3[0], xy_3[1], 1)
            trans_foot_3 = trans_foot_3/trans_foot_3[2]
            trans_x_3 = trans_foot_3[0]
            trans_y_3 = trans_foot_3[1]
            
            
            if poly_3.contains(Point(xy_3[0], xy_3[1])) == True:
            #if xy_3[0] < 446 and xy_3[0] > 177 and xy_3[1] > 270 and xy_3[1] < 400: #before3 = np.float32([[733,718],[203,542],[415,220],[935,131]])
                ROI_image = cv2.circle(ROI_image,(int(trans_x_3),int(trans_y_3)), 3, (255,0,0), -1)

        resize_frame1 = cv2.resize(frame1, (320, 180))
        resize_frame2 = cv2.resize(frame2, (320, 180))
        resize_frame3 = cv2.resize(frame3, (320, 180))
        resize_ROI_image = cv2.resize(ROI_image, (960,540) )
        

        img_con = cv2.vconcat([resize_frame1, resize_frame2,resize_frame3])
        img_hcon = cv2.hconcat([img_con, resize_ROI_image])
    

        
        
        cv2.imshow('mapping', img_hcon)
        
        
        # 영상을 저장한다.
        out1.write(frame1)
        out2.write(frame2)
        out3.write(frame3)
        out4.write(img_hcon)
        
        # 1ms뒤에 뒤에 코드 실행해준다.
        k = cv2.waitKey(1) & 0xff
        #키보드 esc 누르면 종료된다.
        if k == 27:
            break
    video_capture1.release()  # cap 객체 해제
    video_capture2.release()  # cap 객체 해제
    video_capture3.release()  # cap 객체 해제
    out1.release()  # out 객체 해제
    out2.release()  # out 객체 해제
    out3.release()  # out 객체 해제
    out4.release()  # out 객체 해제
    cv2.destroyAllWindows()

if __name__ == "__main__":
    writeVideo()
# Out:
# [710.5115  362.12848]
# [711.2991  355.69385]
# [709.07117 356.25198]
# [707.796   356.70062]
# [883.9697 286.3155]
# [883.0695 285.6329]
# [884.2098  283.52505]
# [885.22986 285.55038]
# [709.5438  365.40274]
# [921.80585 271.37308]
# [884.83984 294.56683]
# [936.0582  294.04178]
# [935.54803 295.97894]
# [950.2505 285.0928]
# [935.1881  301.13135]
# [948.8402  294.85187]
# [947.8201  296.44217]
# [952.1107  288.82843]
# [953.19104 292.77408]
# [952.26074 290.92123]
# [954.6312  287.02063]
# [952.3208 288.6109]
# [955.77136 285.7154 ]
# [957.15155 280.8846 ]
# [956.6115 281.9423]
# [956.1315 283.8251]
# [961.23224 280.202  ]
# [958.77185 285.34784]
# [959.192  288.1908]
# [935.03796 308.2566 ]
# [958.4118  288.31833]
# [935.4281  298.75253]
# [965.193   291.28882]
# [965.67303 289.4435 ]
# [978.75507 298.26495]
# [976.41473 294.00427]
# [972.81415 290.21613]
# [975.9347  303.05072]
# [970.11365 304.65225]
# [974.67444 295.13693]
# [976.29474 292.72156]
# [983.67596 293.78674]
# [983.25586 294.67188]
# [983.6159  295.43698]
# [986.3164  291.64886]
# [988.53674 292.44403]
# [987.6966  291.53635]
# [987.63654 290.15613]
# [986.25635 291.63385]
# [987.9967  292.18896]
# [988.2367 291.8439]
# [986.6164  292.11395]
# [991.4772  290.95877]
# [979.5353  297.00473]
# [991.0571  292.67654]
# [989.4369 291.8439]
# [994.59766 292.66904]
# [994.7178  292.04645]
# [992.7374  290.86124]
# [976.6548  292.78156]
# [973.2342  290.47867]
# [981.7557  277.65158]
# [964.7728  289.59354]
# [981.8156 274.216 ]
# [945.9598  282.10733]
# [976.23474 268.14005]
# [973.3543 265.8747]
# [974.67444 256.99323]
# [965.973  259.8137]
# [960.57214 261.01385]
# [941.21906 271.12555]
# [952.2008  246.82158]
# [937.46844 240.73059]
# [935.308  240.0855]
# [911.39417 233.67944]
# [923.15607 219.89218]
# [925.10645 214.4913 ]
# [918.20526 214.64136]
# [905.54315 208.38533]
# [910.404   201.73924]
# [900.5324  195.30319]
# [736.5558    76.483864]
# [758.4743    61.931496]
# [747.2975   65.38206]
# [718.56775   46.929054]
# [715.4623    26.645752]
# [682.5056    31.206493]
# [656.21344  48.4293 ]
# [713.1969  376.14917]
# [624.495    6.6625]
# [713.5344 363.2275]
# [712.6719 366.2832]
# [710.744   364.96094]
# [574.90436  37.3875 ]
# [584.78345     6.1824217]
# [597.8994      1.1416016]
# [604.72546   -4.799365]
# [604.87555     1.7416992]
# [598.37573    9.002881]
# [616.89996     6.1824217]
# [622.97784    3.602002]
# [604.39545  34.26699]
# [626.104      10.0230465]
# [600.9336    37.807568]
# [631.97815  14.28374]
# [632.0733     13.4436035]
# [633.5142    16.024023]
# [704.1654  361.80087]
# [633.7069    18.124365]
# [637.95447   21.484913]
# [649.9545   21.96499]
# [704.9755  364.54715]
# [645.1444    23.525244]
# [649.31555   26.105663]
# [647.9484    25.445557]
# [645.48193   28.746094]
# [645.3115    28.085987]
# [642.798     26.165674]
# [642.006     30.486378]
# [641.68634   30.486378]
# [639.5677    30.366358]
# [634.98645   28.866114]
# [638.54895   30.486378]
# [637.78033  32.82676]
# [636.179     30.906445]
# [634.7655    34.627052]
# [633.0951   37.92759]
# [630.21936   40.928078]
# [626.7069    40.868065]
# [624.615    40.20796]
# [626.9525   37.92759]
# [617.5582    55.840504]
# [626.5709    40.508007]
# [624.74817  42.24829]
# [627.4721   42.78838]
# [622.51843  42.78838]
# [632.707     48.339283]
# [614.3294   45.54883]
# [604.613     44.288624]
# [596.1554    40.267967]
# [592.9223   43.02842]
# [588.93176   38.947754]
# [585.8937    38.467674]
# [583.1857    36.607372]
# [577.8749   37.20747]
# [574.5444    36.847412]
# [569.44354   36.607372]
# [559.797    34.20698]
# [567.1331    47.859203]
# [548.17004   42.278297]
# [547.31494  37.74756]
# [536.27313  34.26699]
# [533.3177   34.74707]
# [524.4362   32.52671]
# [521.9608   27.48589]
# [517.3851    25.205517]
# [516.60486   28.506054]
# [506.31323  29.52622]
# [491.88086  27.06582]
# [476.3834    17.404247]
# [447.6687    18.724463]
# [430.41592   21.664942]
# [424.83496   14.703809]
# [404.76172   30.816431]
# [387.4789    27.785938]
# [314.267    -3.59917]
# [242.73535  37.62754]
# [242.01523   28.866114]
# [258.63794    4.322119]
# [274.06046  -10.020215]
# [271.9601     6.122412]
# [277.24097     -0.89873046]
# [286.96255    5.942383]
# [283.18195   9.30293]
# [286.42245    11.7033205]
# [288.40277   20.044678]
# [299.68463   9.30293]
# [308.38605   10.203076]
# [319.00775  16.86416]
# [320.80804   21.544922]
# [319.42783  41.76821]
# [329.1494   45.51882]
# [347.00232   47.979225]
# [353.15332   57.340748]
# [357.384     58.300903]
# [364.7052    58.000854]
# [374.09674  62.41157]
# [388.22903   59.531105]
# [390.71942   70.422874]
# [437.40704   30.306347]
# [396.54037  74.56355]
# [399.0008   87.04558]
# [400.14096   97.277245]
# [404.6417  108.58909]
# [405.30182 117.23049]
# [408.72235 123.53152]
# [411.27277 132.26294]
# [413.73322 139.25407]
# [418.98404 144.17488]
# [421.02435 152.2762 ]
# [429.33575 158.69724]
# [433.74643 170.18912]
# [439.77744 180.15073]
# [445.98843 188.19205]
# [457.06024 197.88362]
# [462.73114 204.5147 ]
# [469.27222 208.08528]
# [471.79263 215.81152]
# [482.3243 219.2021]
# [486.49503 226.83833]
# [492.91608 231.44409]
# [502.08252 237.20503]
# [513.6344  245.98145]
# [517.7001  254.15776]
# [523.38605 261.98904]
# [527.06165 268.3351 ]
# [534.2778 279.3919]
# [542.8292  280.32953]
# [547.46497 289.9686 ]
# [552.8959 294.2143]
# [559.0168  301.93304]
# [567.5082  306.14874]
# [744.53705 272.6258 ]
# [578.4     308.39157]
# [757.03406 262.2591 ]
# [588.63165 312.86234]
# [601.65375 311.48212]
# [615.2422  311.22708]
# [625.74207 310.837  ]
# [634.9533  308.27908]
# [644.2222 310.9945]
# [653.2406  312.32224]
# [666.88434 310.08688]
# [678.1175 311.3771]
# [687.3102  319.44092]
# [701.26245 324.86053]
# [713.767  331.3791]
# [728.6644  332.56427]
# [742.9618  332.56805]
# [750.0429  335.39224]
# [756.929   335.51978]
# [765.1203 335.531 ]
# [770.9713  335.67355]
# [774.4219  336.98813]
# [777.7974  340.10114]
# [782.41815 341.92206]
# [790.90955 342.40027]
# [797.58563 340.9488 ]
# [803.6166  336.98248]
# [808.0874  332.73682]
# [816.24866 331.8929 ]
# [810.2477  337.74457]
# [822.87976 329.8976 ]
# [827.2904  331.26282]
# [831.0111  332.11798]
# [835.60187 333.94077]
# [840.4626  336.98438]
# [843.67316 337.03873]
# [837.0121  341.79828]

# %%
#카메라 3대  원하는 영역에서 검출된 발만 mapping
#발의 중앙

import cv2
import datetime
import os

from shapely.geometry import Point
from shapely.geometry.polygon import Polygon


ROI_image = cv2.imread('C:/Users/Leeyourack/jookyoung/image/0.ROI_image/pre_image_final.jpg')

def writeVideo():
    global ROI_image
    #현재시간 가져오기
    currentTime = datetime.datetime.now()
    
    #RTSP를 불러오는 곳
    video_capture1 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test1.avi")
    video_capture2 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test2.avi")
    video_capture3 = cv2.VideoCapture("C:/Users/Leeyourack/jookyoung/video/1.test_video/new_test3.avi")
    

    # 웹캠 설정
    video_capture1.set(3, 800)  # 영상 가로길이 설정
    video_capture1.set(4, 600)  # 영상 세로길이 설정
    # 웹캠 설정
    video_capture2.set(3, 800)  # 영상 가로길이 설정
    video_capture2.set(4, 600)  # 영상 세로길이 설정
    # 웹캠 설정
    video_capture3.set(3, 800)  # 영상 가로길이 설정
    video_capture3.set(4, 600)  # 영상 세로길이 설정
    
    # 가로 길이 가져오기
    streaming_window_width = int(video_capture1.get(3))
    # 세로 길이 가져오기
    streaming_window_height = int(video_capture1.get(4))  

   
    
    
    #현재 시간을 '년도 달 일 시간 분 초'로 가져와서 문자열로 생성
    fileName = str(currentTime.strftime('%Y %m %d %H %M %S'))

    #파일 저장하기 위한 변수 선언
    path1 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test1.avi'
    #파일 저장하기 위한 변수 선언
    path2 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test2.avi'
    #파일 저장하기 위한 변수 선언
    path3 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test3.avi'
    #파일 저장하기 위한 변수 선언
    path4 = 'C:/Users/Leeyourack/jookyoung/video/2.detect_video/test4-2.avi'
    
    # DIVX 코덱 적용 # 코덱 종류 # DIVX, XVID, MJPG, X264, WMV1, WMV2
    # 무료 라이선스의 이점이 있는 XVID를 사용
    fourcc = cv2.VideoWriter_fourcc('X', 'V', 'I', 'D')
    fps = 20
    # 비디오 저장
    # cv2.VideoWriter(저장 위치, 코덱, 프레임, (가로, 세로))
    out1 = cv2.VideoWriter(path1, fourcc, fps, (streaming_window_width, streaming_window_height))
    out2 = cv2.VideoWriter(path2, fourcc, fps, (streaming_window_width, streaming_window_height))
    out3 = cv2.VideoWriter(path3, fourcc, fps, (streaming_window_width, streaming_window_height))
    out4 = cv2.VideoWriter(path4, fourcc, fps, (1280, 540))

    while True:
        ret1, frame1 = video_capture1.read()
        ret2, frame2 = video_capture2.read()
        ret3, frame3 = video_capture3.read()
        
        img1 = frame1.copy()
        img2 = frame2.copy()
        img3 = frame3.copy()

        results1 = model.detect_poses(img1, skeleton='smpl_24')
        keypoints_with1 = results1['poses2d'].numpy()
        results2 = model.detect_poses(img2, skeleton='smpl_24')
        keypoints_with2 = results2['poses2d'].numpy()
        results3 = model.detect_poses(img3, skeleton='smpl_24')
        keypoints_with3 = results3['poses2d'].numpy()

        loop_through_people(frame1, keypoints_with1)
        foot_xy1 = results1['poses2d'].numpy()[:,23]

        loop_through_people(frame2, keypoints_with2)
        foot_xy2 = results2['poses2d'].numpy()[:,23]

        loop_through_people(frame3, keypoints_with3)
        foot_xy3 = results3['poses2d'].numpy()[:,23]
        
        poly_list_1 = [(346, 623), (915,401), (714, 155), (169,92)]
        poly_1 = Polygon(poly_list_1)
        for a, xy_1 in enumerate(foot_xy1):
            trans_foot_1 = M1@(xy_1[0], xy_1[1], 1)
            trans_foot_1 = trans_foot_1/trans_foot_1[2]
            trans_x_1 = trans_foot_1[0]
            trans_y_1 = trans_foot_1[1]
            print(xy_1)
            
            if poly_1.contains(Point(xy_1[0], xy_1[1])) == True:

            #if xy_1[0] < 446 and xy_1[0] > 178 and xy_1[1] > 270 and xy_1[1] < 408: #before1 = np.float32([[346, 623],[915,401],[714, 155],[169,92]])
         
                ROI_image = cv2.circle(ROI_image,(int(trans_x_1),int(trans_y_1)), 3, (0,0,255), -1)
        
        poly_list_2 = [(942,709), (100,500), (197,306), (983,174)]
        poly_2 = Polygon(poly_list_2)
        for b, xy_2 in enumerate(foot_xy2):
            trans_foot_2 = M2@(xy_2[0], xy_2[1], 1)
            trans_foot_2 = trans_foot_2/trans_foot_2[2]
            trans_x_2 = trans_foot_2[0]
            trans_y_2 = trans_foot_2[1]
            
            
            if poly_2.contains(Point(xy_2[0], xy_2[1])) == True:
            #if xy_2[0] < 383 and xy_2[0] > 291 and xy_2[1] > 81 and xy_2[1] < 235: #before2 = np.float32([[942,709],[100,500],[197,306],[983,174]])
            
                ROI_image = cv2.circle(ROI_image,(int(trans_x_2),int(trans_y_2)), 3, (0,255,0), -1)

        poly_list_3 = [(733,718), (203,542), (415,220), (935,131)]
        poly_3 = Polygon(poly_list_3)
        for c, xy_3 in enumerate(foot_xy3):
            trans_foot_3 = M3@(xy_3[0], xy_3[1], 1)
            trans_foot_3 = trans_foot_3/trans_foot_3[2]
            trans_x_3 = trans_foot_3[0]
            trans_y_3 = trans_foot_3[1]
            
            
            if poly_3.contains(Point(xy_3[0], xy_3[1])) == True:
            #if xy_3[0] < 446 and xy_3[0] > 177 and xy_3[1] > 270 and xy_3[1] < 400: #before3 = np.float32([[733,718],[203,542],[415,220],[935,131]])
                ROI_image = cv2.circle(ROI_image,(int(trans_x_3),int(trans_y_3)), 3, (255,0,0), -1)

        resize_frame1 = cv2.resize(frame1, (320, 180))
        resize_frame2 = cv2.resize(frame2, (320, 180))
        resize_frame3 = cv2.resize(frame3, (320, 180))
        resize_ROI_image = cv2.resize(ROI_image, (960,540) )
        

        img_con = cv2.vconcat([resize_frame1, resize_frame2,resize_frame3])
        img_hcon = cv2.hconcat([img_con, resize_ROI_image])
    

        
        
        cv2.imshow('mapping', img_hcon)
        
        
        # 영상을 저장한다.
        out1.write(frame1)
        out2.write(frame2)
        out3.write(frame3)
        out4.write(img_hcon)
        
        # 1ms뒤에 뒤에 코드 실행해준다.
        k = cv2.waitKey(1) & 0xff
        #키보드 esc 누르면 종료된다.
        if k == 27:
            break
    video_capture1.release()  # cap 객체 해제
    video_capture2.release()  # cap 객체 해제
    video_capture3.release()  # cap 객체 해제
    out1.release()  # out 객체 해제
    out2.release()  # out 객체 해제
    out3.release()  # out 객체 해제
    out4.release()  # out 객체 해제
    cv2.destroyAllWindows()

if __name__ == "__main__":
    writeVideo()
# Out:
# [705.7932  358.04898]
# [700.51984 357.31268]
# [703.13025 360.5832 ]
# [705.3207 357.6516]

# %%
import cv2
import time


# 동영상 파일 읽기 (video_play.py)

import cv2

video_file = "C:/Users/Leeyourack/jookyoung/video/2.detect_video/test4.avi" # 동영상 파일 경로

cap = cv2.VideoCapture(video_file) # 동영상 캡쳐 객체 생성  ---①
if cap.isOpened():                 # 캡쳐 객체 초기화 확인
    while True:
        ret, img = cap.read()      # 다음 프레임 읽기      --- ②
        if ret:                     # 프레임 읽기 정상
            cv2.imshow(video_file, img) # 화면에 표시  --- ③
            cv2.waitKey(75)            # 25ms 지연(40fps로 가정)   --- ④
        else:                       # 다음 프레임 읽을 수 없슴,
            break                   # 재생 완료
else:
    print("can't open video.")      # 캡쳐 객체 초기화 실패
cap.release()                       # 캡쳐 자원 반납
cv2.destroyAllWindows()
